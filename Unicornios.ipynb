# %%
#Bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Leitura de dados
Base_Dados = pd.read_csv("Unicorns in June 2022s end - june 2022.csv")
Base_Dados.shape
# Out:
# (1170, 7)

# %%
#Primeiros Registros
Base_Dados.head()
# Out:
#      Company Valuation ($B) Date Joined        Country          City   \
# 0  ByteDance           $140    4/7/2017          China        Beijing
# 1     SpaceX           $127   12/1/2012  United States      Hawthorne
# 2      SHEIN           $100    7/3/2018          China       Shenzhen
# 3     Stripe            $95   1/23/2014  United States  San Francisco
# 4     Klarna         $45.60  12/12/2011         Sweden      Stockholm
#
#                           Industry  \
# 0          Artificial intelligence
# 1                            Other
# 2  E-commerce & direct-to-consumer
# 3                          Fintech
# 4                          Fintech
#
#                                            Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2  Tiger Global Management, Sequoia Capital China...
# 3        Khosla Ventures, LowercaseCapital, capitalG
# 4  Institutional Venture Partners, Sequoia Capita...

# %%
#Colunas
Base_Dados.columns
# Out:
# Index(['Company', 'Valuation ($B)', 'Date Joined', 'Country', 'City ',
#        'Industry', 'Investors'],
#       dtype='object')

# %%
#Renomear
Base_Dados.rename(columns={
        "#": 'Id',
        "Company": 'Empresa',
        "Valuation ($B)": "Valor($)",
        "Date Joined": "Data de Adesão",
        "Country": "País",
        "City": "Cidade",
        "Industry": "Industria",
        "Investors": "Investidores"
    }, inplace=True
)

# %%
#Verificar tipo
Base_Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1170 entries, 0 to 1169
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Empresa         1170 non-null   object
#  1   Valor($)        1170 non-null   object
#  2   Data de Adesão  1170 non-null   object
#  3   País            1170 non-null   object
#  4   City            1170 non-null   object
#  5   Industria       1170 non-null   object
#  6   Investidores    1152 non-null   object
# dtypes: object(7)
# memory usage: 64.1+ KB

# %%
# Campos Nulos
Base_Dados.isnull().sum()
# Out:
# Empresa            0
# Valor($)           0
# Data de Adesão     0
# País               0
# City               0
# Industria          0
# Investidores      18
# dtype: int64

# %%
plt.figure(figsize=(15,6))
plt.title("Analisando Campos Nulos")
sns.heatmap(Base_Dados.isnull(), cbar=False);

# %%
# Campos Unicos
Base_Dados.nunique()
# Out:
# Empresa           1167
# Valor($)           219
# Data de Adesão     683
# País                48
# City               282
# Industria           33
# Investidores      1136
# dtype: int64

# %%
#Valores Unicos
Base_Dados['Industria'].unique()
# Out:
# array(['Artificial intelligence', 'Other',
#        'E-commerce & direct-to-consumer', 'Fintech',
#        'Internet software & services',
#        'Supply chain, logistics, & delivery',
#        'Data management & analytics',
#        'Sequoia Capital, Thoma Bravo, Softbank', 'Edtech', 'Hardware',
#        'Consumer & retail', 'Health', 'Auto & transportation',
#        'Cybersecurity', 'Mobile & telecommunications', 'Travel',
#        'Kuang-Chi',
#        'Tiger Global Management, Tiger Brokers, DCM Ventures',
#        'Jungle Ventures, Accel, Venture Highway',
#        'Artificial Intelligence', 'GIC. Apis Partners, Insight Partners',
#        'Vision Plus Capital, GSR Ventures, ZhenFund',
#        'Hopu Investment Management, Boyu Capital, DC Thomson Ventures',
#        '500 Global, Rakuten Ventures, Golden Gate Ventures',
#        'Sequoia Capital China, ING, Alibaba Entrepreneurs Fund',
#        'Sequoia Capital China, Shunwei Capital Partners, Qualgro',
#        'Dragonfly Captial, Qiming Venture Partners, DST Global',
#        'SingTel Innov8, Alpha JWC Ventures, Golden Gate Ventures',
#        'Mundi Ventures, Doqling Capital Partners, Activant Capital',
#        'Vertex Ventures SE Asia, Global Founders Capital, Visa Ventures',
#        'Andreessen Horowitz, DST Global, IDG Capital',
#        "B Capital Group, Monk's Hill Ventures, Dynamic Parcel Distribution",
#        'Temasek, Guggenheim Investments, Qatar Investment Authority'],
#       dtype=object)

# %%
# Valores Unicos Rank
Base_Dados['Industria'].value_counts()
# Out:
# Fintech                                                               236
# Internet software & services                                          221
# E-commerce & direct-to-consumer                                       105
# Health                                                                 90
# Artificial intelligence                                                74
# Other                                                                  65
# Supply chain, logistics, & delivery                                    62
# Cybersecurity                                                          58
# Data management & analytics                                            44
# Auto & transportation                                                  39
# Hardware                                                               38
# Mobile & telecommunications                                            37
# Edtech                                                                 31
# Consumer & retail                                                      28
# Travel                                                                 14
# Artificial Intelligence                                                11
# Sequoia Capital China, ING, Alibaba Entrepreneurs Fund                  1
# B Capital Group, Monk's Hill Ventures, Dynamic Parcel Distribution      1
# Andreessen Horowitz, DST Global, IDG Capital                            1
# Vertex Ventures SE Asia, Global Founders Capital, Visa Ventures         1
# Mundi Ventures, Doqling Capital Partners, Activant Capital              1
# SingTel Innov8, Alpha JWC Ventures, Golden Gate Ventures                1
# Dragonfly Captial, Qiming Venture Partners, DST Global                  1
# Sequoia Capital China, Shunwei Capital Partners, Qualgro                1
# Kuang-Chi                                                               1
# 500 Global, Rakuten Ventures, Golden Gate Ventures                      1
# Hopu Investment Management, Boyu Capital, DC Thomson Ventures           1
# Vision Plus Capital, GSR Ventures, ZhenFund                             1
# GIC. Apis Partners, Insight Partners                                    1
# Jungle Ventures, Accel, Venture Highway                                 1
# Tiger Global Management, Tiger Brokers, DCM Ventures                    1
# Sequoia Capital, Thoma Bravo, Softbank                                  1
# Temasek, Guggenheim Investments, Qatar Investment Authority             1
# Name: Industria, dtype: int64

# %%
# % valores unicos
round(Base_Dados['Industria'].value_counts(normalize=True) * 100, 2)
# Out:
# Fintech                                                               20.17
# Internet software & services                                          18.89
# E-commerce & direct-to-consumer                                        8.97
# Health                                                                 7.69
# Artificial intelligence                                                6.32
# Other                                                                  5.56
# Supply chain, logistics, & delivery                                    5.30
# Cybersecurity                                                          4.96
# Data management & analytics                                            3.76
# Auto & transportation                                                  3.33
# Hardware                                                               3.25
# Mobile & telecommunications                                            3.16
# Edtech                                                                 2.65
# Consumer & retail                                                      2.39
# Travel                                                                 1.20
# Artificial Intelligence                                                0.94
# Sequoia Capital China, ING, Alibaba Entrepreneurs Fund                 0.09
# B Capital Group, Monk's Hill Ventures, Dynamic Parcel Distribution     0.09
# Andreessen Horowitz, DST Global, IDG Capital                           0.09
# Vertex Ventures SE Asia, Global Founders Capital, Visa Ventures        0.09
# Mundi Ventures, Doqling Capital Partners, Activant Capital             0.09
# SingTel Innov8, Alpha JWC Ventures, Golden Gate Ventures               0.09
# Dragonfly Captial, Qiming Venture Partners, DST Global                 0.09
# Sequoia Capital China, Shunwei Capital Partners, Qualgro               0.09
# Kuang-Chi                                                              0.09
# 500 Global, Rakuten Ventures, Golden Gate Ventures                     0.09
# Hopu Investment Management, Boyu Capital, DC Thomson Ventures          0.09
# Vision Plus Capital, GSR Ventures, ZhenFund                            0.09
# GIC. Apis Partners, Insight Partners                                   0.09
# Jungle Ventures, Accel, Venture Highway                                0.09
# Tiger Global Management, Tiger Brokers, DCM Ventures                   0.09
# Sequoia Capital, Thoma Bravo, Softbank                                 0.09
# Temasek, Guggenheim Investments, Qatar Investment Authority            0.09
# Name: Industria, dtype: float64

# %%
plt.figure(figsize=(15,6))
plt.title("Analise dos Setores")
plt.bar(Base_Dados['Industria'].value_counts().index, Base_Dados['Industria'].value_counts())
plt.xticks(rotation=45, ha='right');

# %%
#Paises com mais Unicornios
Base_Dados['País'].value_counts()
# Out:
# United States           628
# China                   174
# India                    68
# United Kingdom           44
# Germany                  29
# France                   25
# Israel                   21
# Canada                   19
# Brazil                   17
# South Korea              15
# Singapore                13
# Australia                 8
# Sweden                    8
# Hong Kong                 7
# Mexico                    7
# Netherlands               7
# Japan                     6
# Ireland                   6
# Switzerland               6
# Indonesia                 6
# Norway                    5
# Spain                     4
# Finland                   4
# Belgium                   3
# Turkey                    3
# United Arab Emirates      3
# Colombia                  3
# Denmark                   2
# South Africa              2
# Croatia                   2
# Philippines               2
# Chile                     2
# Thailand                  2
# Estonia                   2
# Austria                   2
# Lithuania                 2
# Vietnam                   2
# Czech Republic            1
# Bermuda                   1
# Ecuador                   1
# Bahamas                   1
# Malaysia                  1
# Senegal                   1
# Nigeria                   1
# Luxembourg                1
# Argentina                 1
# Seychelles                1
# Italy                     1
# Name: País, dtype: int64

# %%
# % Paises com mais Unicornios
Analise = round(Base_Dados['País'].value_counts(normalize=True) * 100, 2)
print(Analise)
# Out:
# United States           53.68
# China                   14.87
# India                    5.81
# United Kingdom           3.76
# Germany                  2.48
# France                   2.14
# Israel                   1.79
# Canada                   1.62
# Brazil                   1.45
# South Korea              1.28
# Singapore                1.11
# Australia                0.68
# Sweden                   0.68
# Hong Kong                0.60
# Mexico                   0.60
# Netherlands              0.60
# Japan                    0.51
# Ireland                  0.51
# Switzerland              0.51
# Indonesia                0.51
# Norway                   0.43
# Spain                    0.34
# Finland                  0.34
# Belgium                  0.26
# Turkey                   0.26
# United Arab Emirates     0.26
# Colombia                 0.26
# Denmark                  0.17
# South Africa             0.17
# Croatia                  0.17
# Philippines              0.17
# Chile                    0.17
# Thailand                 0.17
# Estonia                  0.17
# Austria                  0.17
# Lithuania                0.17
# Vietnam                  0.17
# Czech Republic           0.09
# Bermuda                  0.09
# Ecuador                  0.09
# Bahamas                  0.09
# Malaysia                 0.09
# Senegal                  0.09
# Nigeria                  0.09
# Luxembourg               0.09
# Argentina                0.09
# Seychelles               0.09
# Italy                    0.09
# Name: País, dtype: float64

# %%
plt.figure(figsize=(15,6), facecolor='white')
plt.title("Analise de Paises Geradores de Unicornios - TOP 5")
colors = ( "orange", "cyan", "brown",
          "grey", "indigo")
plt.pie(
    Analise.head(5),
    colors=colors,
    labels= Analise.index[0:5],
    shadow=True,
    startangle=50,
    autopct='%1.1f%%'
);

# %%
#Conversão Data
Base_Dados['Data de Adesão'] = pd.to_datetime(Base_Dados['Data de Adesão'])
Base_Dados['Data de Adesão'].head()
# Out:
# 0   2017-04-07
# 1   2012-12-01
# 2   2018-07-03
# 3   2014-01-23
# 4   2011-12-12
# Name: Data de Adesão, dtype: datetime64[ns]

# %%
Base_Dados['Mes'] = pd.DatetimeIndex(Base_Dados['Data de Adesão']).month
Base_Dados['Ano'] = pd.DatetimeIndex(Base_Dados['Data de Adesão']).year
Base_Dados.head()
# Out:
#      Empresa Valor($) Data de Adesão           País          City   \
# 0  ByteDance     $140     2017-04-07          China        Beijing
# 1     SpaceX     $127     2012-12-01  United States      Hawthorne
# 2      SHEIN     $100     2018-07-03          China       Shenzhen
# 3     Stripe      $95     2014-01-23  United States  San Francisco
# 4     Klarna   $45.60     2011-12-12         Sweden      Stockholm
#
#                          Industria  \
# 0          Artificial intelligence
# 1                            Other
# 2  E-commerce & direct-to-consumer
# 3                          Fintech
# 4                          Fintech
#
#                                         Investidores  Mes   Ano
# 0  Sequoia Capital China, SIG Asia Investments, S...    4  2017
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...   12  2012
# 2  Tiger Global Management, Sequoia Capital China...    7  2018
# 3        Khosla Ventures, LowercaseCapital, capitalG    1  2014
# 4  Institutional Venture Partners, Sequoia Capita...   12  2011

# %%
#Tabela Analitica
Analise_Agrupada = Base_Dados.groupby(by=['País', 'Mes', 'Ano', 'Empresa']).count().reset_index()
Analise_Agrupada
# Out:
#                País  Mes   Ano    Empresa  Valor($)  Data de Adesão  City   \
# 0         Argentina    8  2021       Uala         1               1      1
# 1         Australia    1  2018      Canva         1               1      1
# 2         Australia    3  2019  Airwallex         1               1      1
# 3         Australia    3  2022  Immutable         1               1      1
# 4         Australia    3  2022   LinkTree         1               1      1
# ...             ...  ...   ...        ...       ...             ...    ...
# 1165  United States   12  2021     Turing         1               1      1
# 1166  United States   12  2021       Veho         1               1      1
# 1167  United States   12  2021  YipitData         1               1      1
# 1168        Vietnam   10  2021  Sky Mavis         1               1      1
# 1169        Vietnam   12  2021       MoMo         1               1      1
#
#       Industria  Investidores
# 0             1             1
# 1             1             1
# 2             1             1
# 3             1             1
# 4             1             1
# ...         ...           ...
# 1165          1             1
# 1166          1             1
# 1167          1             1
# 1168          1             1
# 1169          1             1
#
# [1170 rows x 9 columns]

# %%
Analise_Agrupada.loc[
    Analise_Agrupada['País'] == 'Brazil'
]
# Out:
#       País  Mes   Ano           Empresa  Valor($)  Data de Adesão  City   \
# 16  Brazil    1  2020              Loft         1               1      1
# 17  Brazil    1  2021    MadeiraMadeira         1               1      1
# 18  Brazil    2  2022              Neon         1               1      1
# 19  Brazil    5  2022              Dock         1               1      1
# 20  Brazil    6  2019             Loggi         1               1      1
# 21  Brazil    7  2018            Movile         1               1      1
# 22  Brazil    8  2021         Nuvemshop         1               1      1
# 23  Brazil    8  2021             Unico         1               1      1
# 24  Brazil    9  2019       QuintoAndar         1               1      1
# 25  Brazil    9  2021         CloudWalk         1               1      1
# 26  Brazil   10  2019             EBANX         1               1      1
# 27  Brazil   10  2021            CargoX         1               1      1
# 28  Brazil   11  2018             iFood         1               1      1
# 29  Brazil   12  2019  Wildlife Studios         1               1      1
# 30  Brazil   12  2020           C6 Bank         1               1      1
# 31  Brazil   12  2020          Creditas         1               1      1
# 32  Brazil   12  2021             Olist         1               1      1
#
#     Industria  Investidores
# 16          1             1
# 17          1             1
# 18          1             1
# 19          1             1
# 20          1             1
# 21          1             1
# 22          1             1
# 23          1             1
# 24          1             1
# 25          1             1
# 26          1             1
# 27          1             1
# 28          1             1
# 29          1             1
# 30          1             1
# 31          1             1
# 32          1             1

# %%
#Conversão de valor para float
Base_Dados['Valor($)'] = pd.to_numeric(Base_Dados['Valor($)'].apply( lambda linha: linha.replace('$', '')))
Base_Dados.head()
# Out:
#      Empresa  Valor($) Data de Adesão           País          City   \
# 0  ByteDance     140.0     2017-04-07          China        Beijing
# 1     SpaceX     127.0     2012-12-01  United States      Hawthorne
# 2      SHEIN     100.0     2018-07-03          China       Shenzhen
# 3     Stripe      95.0     2014-01-23  United States  San Francisco
# 4     Klarna      45.6     2011-12-12         Sweden      Stockholm
#
#                          Industria  \
# 0          Artificial intelligence
# 1                            Other
# 2  E-commerce & direct-to-consumer
# 3                          Fintech
# 4                          Fintech
#
#                                         Investidores  Mes   Ano
# 0  Sequoia Capital China, SIG Asia Investments, S...    4  2017
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...   12  2012
# 2  Tiger Global Management, Sequoia Capital China...    7  2018
# 3        Khosla Ventures, LowercaseCapital, capitalG    1  2014
# 4  Institutional Venture Partners, Sequoia Capita...   12  2011

# %%
#Ranking de Paises com mais valuable
Analise_Pais = Base_Dados.groupby(by=['País']).sum()['Valor($)'].reset_index().sort_values(by="Valor($)", ascending=False)
Analise_Pais
# Out:
#                     País  Valor($)
# 46         United States   2055.04
# 9                  China    674.09
# 45        United Kingdom    202.75
# 20                 India    198.22
# 18               Germany     77.38
# 40                Sweden     62.52
# 17                France     57.02
# 1              Australia     54.40
# 7                 Canada     49.23
# 23                Israel     44.72
# 6                 Brazil     40.08
# 3                Bahamas     32.00
# 38           South Korea     31.52
# 21             Indonesia     28.00
# 30           Netherlands     22.46
# 36             Singapore     20.75
# 19             Hong Kong     20.35
# 29                Mexico     17.50
# 43                Turkey     15.77
# 16               Finland     12.46
# 41           Switzerland     11.30
# 22               Ireland     10.05
# 35            Seychelles     10.00
# 15               Estonia      9.90
# 4                Belgium      8.95
# 25                 Japan      8.82
# 2                Austria      7.61
# 10              Colombia      7.40
# 13               Denmark      6.70
# 39                 Spain      6.15
# 26             Lithuania      6.13
# 32                Norway      5.70
# 47               Vietnam      5.27
# 44  United Arab Emirates      5.05
# 33           Philippines      3.00
# 11               Croatia      3.00
# 37          South Africa      2.59
# 8                  Chile      2.50
# 42              Thailand      2.50
# 0              Argentina      2.45
# 31               Nigeria      2.00
# 27            Luxembourg      2.00
# 34               Senegal      1.70
# 28              Malaysia      1.70
# 5                Bermuda      1.60
# 14               Ecuador      1.50
# 12        Czech Republic      1.20
# 24                 Italy      1.00

# %%
plt.figure(figsize=(15,6))
plt.title('Analise de Paises com mais Valuable')
plt.plot(Analise_Pais['País'], Analise_Pais['Valor($)'])
plt.xticks(rotation=45, ha="right");
